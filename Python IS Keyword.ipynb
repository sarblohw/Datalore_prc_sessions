# %%
#is vs ==
lst1=["Krish","Krish1","Krish2"]
lst2=["Krish","Krish1","Krish2"]
lst1==lst2

# %%
a="Krish"
b="Krish"
a==b

# %%
lst1=["Krish","Krish1","Krish2"]
lst2=lst1
lst1 is lst2

# %%
lst2 is lst1

# %%
lst2[0]="Krish2"

# %%
lst2

# %%
lst1
